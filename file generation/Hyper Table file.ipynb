# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ht_cgc = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone3-Stock_Price_Prediction/data from notebooks/hyper_table_cgc.csv')
ht_crlbf = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone3-Stock_Price_Prediction/data from notebooks/hyper_table_crlbf.csv')
ht_cron = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone3-Stock_Price_Prediction/data from notebooks/hyper_table_cron.csv')
ht_curlf = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone3-Stock_Price_Prediction/data from notebooks/hyper_table_curlf.csv')
ht_gtbif = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone3-Stock_Price_Prediction/data from notebooks/hyper_table_gtbif.csv')
ht_iipr = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone3-Stock_Price_Prediction/data from notebooks/hyper_table_iipr.csv')
ht_tcnnf = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone3-Stock_Price_Prediction/data from notebooks/hyper_table_tcnnf.csv')
ht_tlry = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone3-Stock_Price_Prediction/data from notebooks/hyper_table_tlry.csv')
ht_trssf = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone3-Stock_Price_Prediction/data from notebooks/hyper_table_trssf.csv')
ht_vrnof = pd.read_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone3-Stock_Price_Prediction/data from notebooks/hyper_table_vrnof.csv')

# %%
ht_list = [ht_cgc, ht_crlbf, ht_cron, ht_curlf, ht_gtbif, ht_iipr, ht_tcnnf, ht_tlry, ht_trssf, ht_vrnof]
hyper_table = pd.concat(ht_list)
hyper_table
# Out:
#    Unnamed: 0  stock     version               model      rmse       mae  \
# 0           1    cgc      1+ETFs  LinearRegression()  0.374605  0.258421
# 0           1  crlbf      1+ETFs  LinearRegression()  0.187848  0.149452
# 0           3   cron  All stocks  LinearRegression()  0.141724  0.113036
# 0           1  curlf      1+ETFs  LinearRegression()  0.182203  0.142273
# 0           2  gtbif  1+ETFs+Dow  LinearRegression()  0.355154  0.273537
# 0           0   iipr       1+Dow  LinearRegression()  5.107221  4.160234
# 0           1  tcnnf      1+ETFs  LinearRegression()  0.386340  0.305602
# 0           0   tlry       1+Dow  LinearRegression()  1.289206  1.054205
# 0           1  trssf      1+ETFs  LinearRegression()  0.162104  0.126405
# 0           1  vrnof      1+ETFs  LinearRegression()  0.249591  0.202206
#
#    actual_price  predicted_price  rows  train_rows  test_rows  columns
# 0      5.190000         6.002075  2047        1842        205      160
# ...

# %%
hyper_table = hyper_table.reset_index()
hyper_table = hyper_table.drop('index', axis=1)
hyper_table = hyper_table.rename(columns={'Unnamed: 0':'version run'})
hyper_table
# Out:
#    version run  stock     version               model      rmse       mae  \
# 0            1    cgc      1+ETFs  LinearRegression()  0.374605  0.258421
# 1            1  crlbf      1+ETFs  LinearRegression()  0.187848  0.149452
# 2            3   cron  All stocks  LinearRegression()  0.141724  0.113036
# 3            1  curlf      1+ETFs  LinearRegression()  0.182203  0.142273
# 4            2  gtbif  1+ETFs+Dow  LinearRegression()  0.355154  0.273537
# 5            0   iipr       1+Dow  LinearRegression()  5.107221  4.160234
# 6            1  tcnnf      1+ETFs  LinearRegression()  0.386340  0.305602
# 7            0   tlry       1+Dow  LinearRegression()  1.289206  1.054205
# 8            1  trssf      1+ETFs  LinearRegression()  0.162104  0.126405
# 9            1  vrnof      1+ETFs  LinearRegression()  0.249591  0.202206
#
#    actual_price  predicted_price  rows  train_rows  test_rows  columns
# 0      5.190000         6.002075  2047        1842        205      160
# ...

# %%
hyper_table.to_csv('C:/Users/marki/Desktop/SB Data Science BC/Springboard/Capstone3-Stock_Price_Prediction/report/hyper_table_final.csv', index=True)
